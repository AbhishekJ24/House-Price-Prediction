# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('before.csv')
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# ...

# %% [markdown]
# #####  - Right now, our dataset has alot of extra features.
# ##### - We should only have necessary features which reduces computational load and redundancy, we could take reference of olx.in, they have basic features such as no. of bedrooms, bathrooms, total area, etc....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# ##### - Now, that we can stay assured as our dataset doesn't have any null values, we came across a very clean and balanced dataset.
# ##### - Now we are gonna use only the helpful features

# %%
selected_features = df[['living area', 'number of floors', 'Built Year', 'Price', 'number of bedrooms', 'number of bathrooms']]
selected_features.columns = ['living_area', 'number_of_floors', 'built_year', 'price', 'bedrooms', 'bathrooms']
new_df = selected_features.copy()
new_df.head()
# Out:
#    living_area  number_of_floors  built_year    price  bedrooms  bathrooms
# 0         3650               2.0        1921  2380000         5       2.50
# 1         2920               1.5        1909  1400000         4       2.50
# 2         2910               1.5        1939  1200000         5       2.75
# 3         3310               2.0        2001   838000         4       2.50
# 4         2710               1.5        1929   805000         3       2.00

# %%
new_df.to_csv('after.csv',index=False)

# %% [markdown]
# ##### - Our dataset is now saved as after.csv, this will now be fed as before.csv for the feature engineering phase
